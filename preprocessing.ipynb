# %% [markdown]
# ## Pre-processing and Data Exploration
# Lets get an idea of the shape of our dataset, it's attributes, and it's null-count. Since the dataset is so large, we will select a subset of the data to focus on.

# %%
import pandas as pd
import numpy as np

# read dataset
df = pd.read_csv('data/covid19.csv')
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204025 entries, 0 to 204024
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    204025 non-null  object
#  1   continent                                   192210 non-null  object
#  2   location                                    204025 non-null  object
#  3   date                                        204025 non-null  object
#  4   total_cases                                 195952 non-null  float64
#  5   new_cases                                   195707 non-null  float64
#  6   new_cases_smoothed                          194530 non-null  float64
#  7   total_deaths                                177222 non-null  float64
#  8   new_deaths                                  177199 non-null  float64
#  9   new_deaths_smoothed                         176035 non-null  float64
#  10  total_cases_per_million                     195051 non-null  float64
#  11  new_cases_per_million                       194806 non-null  float64
#  12  new_cases_smoothed_per_million              193634 non-null  float64
#  13  total_deaths_per_million                    176334 non-null  float64
#  14  new_deaths_per_million                      176311 non-null  float64
#  15  new_deaths_smoothed_per_million             175152 non-null  float64
#  16  reproduction_rate                           151592 non-null  float64
#  17  icu_patients                                26971 non-null   float64
#  18  icu_patients_per_million                    26971 non-null   float64
#  19  hosp_patients                               28904 non-null   float64
#  20  hosp_patients_per_million                   28904 non-null   float64
#  21  weekly_icu_admissions                       6659 non-null    float64
#  22  weekly_icu_admissions_per_million           6659 non-null    float64
#  23  weekly_hosp_admissions                      13226 non-null   float64
#  24  weekly_hosp_admissions_per_million          13226 non-null   float64
#  25  total_tests                                 79385 non-null   float64
#  26  new_tests                                   75401 non-null   float64
#  27  total_tests_per_thousand                    79385 non-null   float64
#  28  new_tests_per_thousand                      75401 non-null   float64
#  29  new_tests_smoothed                          103963 non-null  float64
#  30  new_tests_smoothed_per_thousand             103963 non-null  float64
#  31  positive_rate                               95920 non-null   float64
#  32  tests_per_case                              94058 non-null   float64
#  33  tests_units                                 106786 non-null  object
#  34  total_vaccinations                          56474 non-null   float64
#  35  people_vaccinated                           53875 non-null   float64
#  36  people_fully_vaccinated                     51361 non-null   float64
#  37  total_boosters                              28185 non-null   float64
#  38  new_vaccinations                            46285 non-null   float64
#  39  new_vaccinations_smoothed                   113491 non-null  float64
#  40  total_vaccinations_per_hundred              56474 non-null   float64
#  41  people_vaccinated_per_hundred               53875 non-null   float64
#  42  people_fully_vaccinated_per_hundred         51361 non-null   float64
#  43  total_boosters_per_hundred                  28185 non-null   float64
#  44  new_vaccinations_smoothed_per_million       113491 non-null  float64
#  45  new_people_vaccinated_smoothed              112657 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  112657 non-null  float64
#  47  stringency_index                            158631 non-null  float64
#  48  population                                  202807 non-null  float64
#  49  population_density                          181811 non-null  float64
#  50  median_age                                  168457 non-null  float64
#  51  aged_65_older                               166676 non-null  float64
#  52  aged_70_older                               167575 non-null  float64
#  53  gdp_per_capita                              167468 non-null  float64
#  54  extreme_poverty                             109231 non-null  float64
#  55  cardiovasc_death_rate                       168044 non-null  float64
#  56  diabetes_prevalence                         176374 non-null  float64
#  57  female_smokers                              127078 non-null  float64
#  58  male_smokers                                125337 non-null  float64
#  59  handwashing_facilities                      82512 non-null   float64
#  60  hospital_beds_per_thousand                  149290 non-null  float64
#  61  life_expectancy                             190834 non-null  float64
#  62  human_development_index                     163619 non-null  float64
#  63  excess_mortality_cumulative_absolute        6949 non-null    float64
#  64  excess_mortality_cumulative                 6949 non-null    float64
#  65  excess_mortality                            6949 non-null    float64
#  66  excess_mortality_cumulative_per_million     6949 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 104.3+ MB

# %% [markdown]
# <a id='info'></a>

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.125                  0.125
# 1                    0.125                  0.000
# 2                    0.125                  0.000
# 3                    0.125                  0.000
# 4                    0.125                  0.000
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0                     NaN                              NaN                NaN
# 1                     NaN                              NaN                NaN
# 2                     NaN                              NaN                NaN
# 3                     NaN                              NaN                NaN
# 4                     NaN                              NaN                NaN
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0           NaN                       NaN            NaN
# 1           NaN                       NaN            NaN
# 2           NaN                       NaN            NaN
# 3           NaN                       NaN            NaN
# 4           NaN                       NaN            NaN
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
#
#    weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 0                                 NaN          NaN        NaN
# 1                                 NaN          NaN        NaN
# 2                                 NaN          NaN        NaN
# 3                                 NaN          NaN        NaN
# 4                                 NaN          NaN        NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case tests_units  \
# 0                              NaN            NaN             NaN         NaN
# 1                              NaN            NaN             NaN         NaN
# 2                              NaN            NaN             NaN         NaN
# 3                              NaN            NaN             NaN         NaN
# 4                              NaN            NaN             NaN         NaN
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                 NaN                NaN                      NaN
# 1                 NaN                NaN                      NaN
# 2                 NaN                NaN                      NaN
# 3                 NaN                NaN                      NaN
# 4                 NaN                NaN                      NaN
#
#    total_boosters  new_vaccinations  new_vaccinations_smoothed  \
# 0             NaN               NaN                        NaN
# 1             NaN               NaN                        NaN
# 2             NaN               NaN                        NaN
# 3             NaN               NaN                        NaN
# 4             NaN               NaN                        NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
#
#    new_vaccinations_smoothed_per_million  new_people_vaccinated_smoothed  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
#
#    new_people_vaccinated_smoothed_per_hundred  stringency_index  population  \
# 0                                         NaN              8.33  40099462.0
# 1                                         NaN              8.33  40099462.0
# 2                                         NaN              8.33  40099462.0
# 3                                         NaN              8.33  40099462.0
# 4                                         NaN              8.33  40099462.0
#
#    population_density  median_age  aged_65_older  aged_70_older  \
# 0              54.422        18.6          2.581          1.337
# 1              54.422        18.6          2.581          1.337
# 2              54.422        18.6          2.581          1.337
# 3              54.422        18.6          2.581          1.337
# 4              54.422        18.6          2.581          1.337
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN

# %%
df.shape
# Out:
# (204025, 67)

# %% [markdown]
# ### Duplicates
# Check for duplicate rows and then use a nested for loop to check for duplicate columns as well. We find no duplicates, however are job is not done yet. There is a possibility that there exists 1:1 correlates in our set of features.

# %%
# no duplicate rows
df_dupe = df.duplicated(keep='first')
duplicate_rows = [i for i in df_dupe.index if df_dupe[i]==True]
duplicate_rows

# duplicate columns
def duplicateCols(df):
    duplicateColumnNames = []
    # iterate over all the columns in dataframe
    for x in range(df.shape[1]):
        # select column at xth index.
        col = df.iloc[:, x]
        # list of dupe columns
        lst1 = []
        # iterate over all the columns in DataFrame from (x+1)th index till end
        for y in range(x + 1, df.shape[1]):
            # select column at yth index.
            otherCol = df.iloc[:, y]
            # check if two columns at x & y index are equal
            if col.equals(otherCol):
                # append columns duplicate of column x to a list
                lst1.append(df.columns.values[y])
        # check to see if duplicate columns identified
        for i in lst1:
            # discard list if column has already been identified as a duplicate
            if not any(i in s for s in duplicateColumnNames):
                # if duplicate columns exist add column to duplicate group
                lst1.append(df.columns.values[x])
                duplicateColumnNames.append(lst1)
    return duplicateColumnNames

# no duplicate columns
covid_duplicates = duplicateCols(df)
covid_duplicates
# Out:
# []

# %% [markdown]
# ### Condensing our Dataset
# To narrow down the dataset, we selected records for countries that will provide us a more diverse range of values for each feature. For example, we picked countries from different parts of the world, such as Asia, North America, Europe, Africa, the Middle East; countries with high and low GDP; countries with small and large population sizes etc. We acknowledge that in the real world, picking a sample like this would introduce selection bias and the sampling method would be more random. However, in this project, we make the assumption that our subset of data is reflective of the global population.

# %%
# select out countries
df = df.loc[(df['continent'] == 'Europe') | 
            (df['location'] == 'Canada') | 
            (df['location'] == 'United States of America') |
            (df['location'] == 'Australia')
            ]

microstates = ['San Marino', 'Faeroe Islands', 'Isle of Man', 
               'Guernsey', 'Gibraltar', 'Jersey', 'Vatican', 
               'Liechtenstein', 'Andorra', 'Kosovo', 'Monaco',
               'Belarus', 'Russia', 'North Macedonia', 'Montenegro']

# drop microstates 
df = df[~df['location'].isin(microstates)]

# check which countries we have and put in a list, then drop some unneeded
# columns
countries_lst = df['location'].unique()
countries_lst
# Out:
# array(['Albania', 'Australia', 'Austria', 'Belgium',
#        'Bosnia and Herzegovina', 'Bulgaria', 'Canada', 'Croatia',
#        'Cyprus', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy',
#        'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova',
#        'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Serbia',
#        'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland',
#        'Ukraine', 'United Kingdom'], dtype=object)

# %%
len(countries_lst)
# Out:
# 38

# %% [markdown]
# Create a dictionary indicating the number of records for each country in our transformed dataset

# %%
# find # of records for each country
countries_records_dict = {}
for i in countries_lst:
    # key --> country, value --> # of records for that country 
    countries_records_dict[i] = len(df[(df['location'] == i)])

countries_records_dict
# Out:
# {'Albania': 883,
#  'Australia': 913,
#  'Austria': 883,
#  'Belgium': 904,
#  'Bosnia and Herzegovina': 874,
#  'Bulgaria': 871,
#  'Canada': 916,
#  'Croatia': 883,
#  'Cyprus': 871,
#  'Czechia': 878,
#  'Denmark': 906,
#  'Estonia': 905,
#  'Finland': 910,
#  'France': 915,
#  'Germany': 912,
#  'Greece': 885,
#  'Hungary': 876,
#  'Iceland': 880,
#  'Ireland': 879,
#  'Italy': 908,
#  'Latvia': 882,
#  'Lithuania': 860,
#  'Luxembourg': 884,
#  'Malta': 874,
#  'Moldova': 871,
#  'Netherlands': 881,
#  'Norway': 883,
#  'Poland': 875,
#  'Portugal': 878,
#  'Romania': 882,
#  'Serbia': 882,
#  'Slovakia': 873,
#  'Slovenia': 906,
#  'Spain': 907,
#  'Sweden': 907,
#  'Switzerland': 883,
#  'Ukraine': 876,
#  'United Kingdom': 908}

# %% [markdown]
# ### Feature Selection
# Focus in on a 1 year range (2021-2022) of the data. We do not want to have unequal amounts of months in our range such as a data range with winter months appearing twice and rest of seasons appearing once. We assume winter months to have less cases/deaths compared to other months because of barriers to interaction like weather. We also want to select a range for which we can assume there is sufficient data -- in 2020 countries were not taking COVID-19 as seriously as they were in 2021, more resources are being dedicated to fighting the pandemic and recording data related to it.

# %%
# select 1 year range from 2021-2022
df = df.loc[(df['date'] >= '2021-01-01') & (df['date'] < '2022-01-01')]

# drop date column and other wholly irelevant columns we no longer need
df.drop(['date', 'iso_code', 'continent', 'tests_units'], axis=1, inplace=True)

# %% [markdown]
# In our [initial exploration](#info) we noticed that there are many columns titled 'x_per_n' -- where n is some power of ten -- or '_smoothed'. This is fine if their exists no corresponding raw column in our dataset, but this is not the case. We will remove these columns if they exist as they are essentially duplicates and we will keep only per_n or smoothed columns that do not correlate with another raw column:

# %%
# find all columns ending with 'per_n'
per_columns = [col for col in df.columns if col.endswith(('per_million', 'per_thousand',
                                                          'per_hundred'))]
# find all columns ending with 'smoothed'                                                    
smoothed_columns =[col for col in df.columns if col.endswith('smoothed')]

# %%
per_columns
# Out:
# ['total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'icu_patients_per_million',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions_per_million',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed_per_thousand',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'total_boosters_per_hundred',
#  'new_vaccinations_smoothed_per_million',
#  'new_people_vaccinated_smoothed_per_hundred',
#  'hospital_beds_per_thousand',
#  'excess_mortality_cumulative_per_million']

# %%
smoothed_columns
# Out:
# ['new_cases_smoothed',
#  'new_deaths_smoothed',
#  'new_tests_smoothed',
#  'new_vaccinations_smoothed',
#  'new_people_vaccinated_smoothed']

# %%
# find all corresponding columns if they exist
corr_per_columns = [col.split('_per')[0] for col in per_columns if col.split('_per')[0] in df.columns]
corr_smoothed_columns = [col.split('_smoothed')[0] for col in smoothed_columns if col.split('_smoothed')[0] in df.columns]

# %%
corr_per_columns
# Out:
# ['total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'icu_patients',
#  'hosp_patients',
#  'weekly_icu_admissions',
#  'weekly_hosp_admissions',
#  'total_tests',
#  'new_tests',
#  'new_tests_smoothed',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'new_vaccinations_smoothed',
#  'new_people_vaccinated_smoothed',
#  'excess_mortality_cumulative']

# %%
corr_smoothed_columns
# Out:
# ['new_cases', 'new_deaths', 'new_tests', 'new_vaccinations']

# %%
# find which per_n and smoothed columns without corresponding dupes -- columns to keep
diff_columns1 = [x for x in per_columns if x.split('_per')[0] not in corr_per_columns]
diff_columns2 = [x for x in smoothed_columns if x.split('_smoothed')[0] not in corr_smoothed_columns]

# %%
diff_columns1
# Out:
# ['hospital_beds_per_thousand']

# %%
diff_columns2
# Out:
# ['new_people_vaccinated_smoothed']

# %% [markdown]
# We remove columns that are essentially rescaled duplicates/correlates of another column:

# %%
# remove all the per_n and smoothed columns that have a corresponding raw column
per_columns.remove('hospital_beds_per_thousand')
smoothed_columns.remove('new_people_vaccinated_smoothed')
per_columns.extend(smoothed_columns)

df.drop(per_columns, axis=1, inplace=True)

# return list of resulting columns
len(df.columns)
df.columns
# Out:
# Index(['location', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths',
#        'reproduction_rate', 'icu_patients', 'hosp_patients',
#        'weekly_icu_admissions', 'weekly_hosp_admissions', 'total_tests',
#        'new_tests', 'positive_rate', 'tests_per_case', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_people_vaccinated_smoothed',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality'],
#       dtype='object')

# %% [markdown]
# ### Dealing with Null Values
#
# We created a dataframe that gives us a quick glimpse of the amount of records countaining a null in each column by country. We decided to remove columns where null count totaled 60% or more and reran the DataFrame to get an idea of which cells will need to be filled. We chose 60% because our input variables would be severely limited had we went with 50%.
#
# Null values can severely hurt our models by biasing estimates of paramters. We replaced remaining null values in each column with the median value as it is less resistant to outliers (if their truly are any) than the mean.

# %%
# function for creating a dataframe showing us nulls
def nans(df, countries):
    countries_nans_dict = {}
    for country in countries:
        # create a new list for each country in the dict
        column_nans = []
        # iterate over dataframe columns
        for col in df.columns:
            # append to list sum of null values in each column for current country
            column_nans.append(df.loc[df['location'] == country, [col]].isnull().values.ravel().sum())
            # assign list of sum of nulls in each column as value for country key
            countries_nans_dict[country] = column_nans

    df_nans = pd.DataFrame(data=list(countries_nans_dict.values()), 
                           index=countries_nans_dict.keys(),
                           columns=df.columns)
    # return dataframe containing only columns with at least one null value for any country
    df_nans_dropped = df_nans.loc[:, df_nans.any()]
    return df_nans_dropped

pd.set_option('display.max_columns', None)
nans(df, countries_lst)
# Out:
#                         new_cases  new_deaths  icu_patients  hosp_patients  \
# Albania                         0           0           365            365
# Australia                       0           2             0              0
# Austria                         0           0             0              0
# Belgium                         0           0             0              0
# Bosnia and Herzegovina          0           1           365            365
# Bulgaria                        0           0             0              0
# Canada                          0           1             0              0
# Croatia                         0           0           365              0
# Cyprus                          0           0             0              0
# Czechia                         2           5             0              0
# Denmark                         1           1             0              0
# Estonia                         0           0             0              0
# Finland                         0           0            68             68
# France                          1           0             0              0
# Germany                         0           0             0            365
# Greece                          0           0           365            365
# Hungary                         0           0           365              0
# Iceland                         1           0           322            155
# Ireland                         3           1           314              3
# Italy                           0           0             0              0
# Latvia                          0           0           314              2
# Lithuania                       0           0           365             77
# Luxembourg                      0           0             0              0
# Malta                           0           0           313             25
# Moldova                         0           1           365            365
# Netherlands                     0           0             2              2
# Norway                          0           2           365             54
# Poland                          0           0           365              8
# Portugal                        0           0             0              0
# Romania                         0           0             4             59
# Serbia                          0           0             0              0
# Slovakia                        0           0             0              0
# Slovenia                        0           0             0              0
# Spain                           2           0             0              0
# Sweden                          0           2             0              0
# Switzerland                     0          11             0              0
# Ukraine                         0           0           365            365
# United Kingdom                  2           0             0              0
#
#                         weekly_icu_admissions  weekly_hosp_admissions  \
# Albania                                   365                     365
# Australia                                 365                     365
# Austria                                   365                     365
# Belgium                                   365                       0
# Bosnia and Herzegovina                    365                     365
# Bulgaria                                  365                     365
# Canada                                    365                     365
# Croatia                                   365                     313
# Cyprus                                    313                     313
# Czechia                                     0                       0
# Denmark                                   365                       0
# Estonia                                   315                     313
# Finland                                   365                     365
# France                                      0                       0
# Germany                                   215                       0
# Greece                                    313                     313
# Hungary                                   365                     365
# Iceland                                   365                     313
# Ireland                                   313                     314
# Italy                                       0                       0
# Latvia                                    313                     313
# Lithuania                                 365                     365
# Luxembourg                                365                     313
# Malta                                     328                     313
# Moldova                                   365                     365
# Netherlands                                 8                       8
# Norway                                    313                     313
# Poland                                    365                     365
# Portugal                                  365                     365
# Romania                                   365                     365
# Serbia                                    365                     365
# Slovakia                                  365                     365
# Slovenia                                  313                     313
# Spain                                       0                       0
# Sweden                                    365                     365
# Switzerland                               365                       0
# Ukraine                                   365                     365
# United Kingdom                            365                       0
#
#                         total_tests  new_tests  positive_rate  tests_per_case  \
# Albania                          17         17              0               0
# Australia                         0          0              0             175
# Austria                           2          3             31              31
# Belgium                           0          0              0               0
# Bosnia and Herzegovina          113        166              0               1
# Bulgaria                        132        192              0               0
# Canada                            0          0              0               0
# Croatia                          96        148              0               0
# Cyprus                            0          0              0               0
# Czechia                           0          0              0               0
# Denmark                           0          0              1               1
# Estonia                           0          0              0               0
# Finland                           0          0              0               0
# France                            0          0              0               0
# Germany                         313        365            313             313
# Greece                           32         57              0               0
# Hungary                          60         60              0               0
# Iceland                           1          1            365             365
# Ireland                           0          0              0               0
# Italy                             0          0              0               0
# Latvia                            0          0              0               0
# Lithuania                         0          0              0               0
# Luxembourg                        0          0              0               0
# Malta                             0          0              0               0
# Moldova                         365          0              0               0
# Netherlands                       0          0              0               0
# Norway                            0          0              0               0
# Poland                          313        365              0               0
# Portugal                          0          0              0               0
# Romania                         313        365              0               0
# Serbia                            0          0              0               0
# Slovakia                          0          0              0               0
# Slovenia                          0          0              0               0
# Spain                             0          0              0               0
# Sweden                            0          0              0               0
# Switzerland                       0          0              0               0
# Ukraine                          74        119              0               0
# United Kingdom                    2          3              2               2
#
#                         total_vaccinations  people_vaccinated  \
# Albania                                138                191
# Australia                               54                 56
# Austria                                313                313
# Belgium                                  0                  0
# Bosnia and Herzegovina                 346                345
# Bulgaria                                20                150
# Canada                                   0                  1
# Croatia                                 88                 93
# Cyprus                                 223                224
# Czechia                                  0                  0
# Denmark                                  0                  0
# Estonia                                  1                  1
# Finland                                309                319
# France                                   0                  0
# Germany                                  0                  0
# Greece                                  19                 19
# Hungary                                222                 95
# Iceland                                243                243
# Ireland                                  2                  2
# Italy                                    0                  0
# Latvia                                   0                  0
# Lithuania                                5                  5
# Luxembourg                              33                 33
# Malta                                   27                 27
# Moldova                                170                246
# Netherlands                            313                313
# Norway                                   0                  0
# Poland                                  64                 66
# Portugal                               312                312
# Romania                                  1                 96
# Serbia                                 168                168
# Slovakia                               313                313
# Slovenia                                 5                  5
# Spain                                  121                115
# Sweden                                 314                314
# Switzerland                              0                  0
# Ukraine                                 55                 55
# United Kingdom                           9                  9
#
#                         people_fully_vaccinated  total_boosters  \
# Albania                                     201             336
# Australia                                    59             282
# Austria                                     314             315
# Belgium                                       0             251
# Bosnia and Herzegovina                      347             364
# Bulgaria                                     35             345
# Canada                                        0              41
# Croatia                                     154             365
# Cyprus                                      226             331
# Czechia                                       0             162
# Denmark                                       0              53
# Estonia                                       1               5
# Finland                                     317             345
# France                                        0              25
# Germany                                      14             131
# Greece                                       34             256
# Hungary                                      95             280
# Iceland                                     243             328
# Ireland                                       2             269
# Italy                                         3             255
# Latvia                                        0               2
# Lithuania                                    18              53
# Luxembourg                                  291             102
# Malta                                        33             365
# Moldova                                     200             365
# Netherlands                                 316             352
# Norway                                        5              88
# Poland                                       79             308
# Portugal                                    312             347
# Romania                                      17             365
# Serbia                                      187             295
# Slovakia                                    315             313
# Slovenia                                      7             184
# Spain                                       124             309
# Sweden                                      315             365
# Switzerland                                   0               0
# Ukraine                                      74             349
# United Kingdom                                9             272
#
#                         new_vaccinations  new_people_vaccinated_smoothed  \
# Albania                              200                              10
# Australia                             56                              52
# Austria                              365                               8
# Belgium                                0                               0
# Bosnia and Herzegovina               363                              42
# Bulgaria                              26                               0
# Canada                                 0                               0
# Croatia                              141                               0
# Cyprus                               304                               6
# Czechia                                0                               0
# Denmark                                0                               0
# Estonia                                2                               0
# Finland                              362                               3
# France                                 0                               0
# Germany                                0                               0
# Greece                                38                               0
# Hungary                              238                              18
# Iceland                              318                               0
# Ireland                                4                               0
# Italy                                  0                               0
# Latvia                                 0                               0
# Lithuania                              8                               0
# Luxembourg                            61                               0
# Malta                                 30                              17
# Moldova                              219                              64
# Netherlands                          365                               8
# Norway                                 0                               0
# Poland                               120                               0
# Portugal                             365                               1
# Romania                                2                               0
# Serbia                               242                               8
# Slovakia                             365                               3
# Slovenia                              10                               0
# Spain                                180                               4
# Sweden                               365                               3
# Switzerland                            0                               0
# Ukraine                               57                              55
# United Kingdom                        10                              10
#
#                         aged_70_older  extreme_poverty  \
# Albania                             0                0
# Australia                           0                0
# Austria                             0                0
# Belgium                             0                0
# Bosnia and Herzegovina              0                0
# Bulgaria                            0                0
# Canada                              0                0
# Croatia                             0                0
# Cyprus                              0              365
# Czechia                             0              365
# Denmark                             0                0
# Estonia                             0                0
# Finland                             0              365
# France                              0              365
# Germany                             0              365
# Greece                              0                0
# Hungary                             0                0
# Iceland                             0                0
# Ireland                             0                0
# Italy                               0                0
# Latvia                              0                0
# Lithuania                           0                0
# Luxembourg                          0                0
# Malta                               0                0
# Moldova                             0                0
# Netherlands                         0              365
# Norway                              0                0
# Poland                              0              365
# Portugal                            0                0
# Romania                             0                0
# Serbia                            365              365
# Slovakia                            0                0
# Slovenia                            0              365
# Spain                               0                0
# Sweden                              0                0
# Switzerland                         0              365
# Ukraine                             0                0
# United Kingdom                      0                0
#
#                         handwashing_facilities  \
# Albania                                    365
# Australia                                  365
# Austria                                    365
# Belgium                                    365
# Bosnia and Herzegovina                       0
# Bulgaria                                   365
# Canada                                     365
# Croatia                                    365
# Cyprus                                     365
# Czechia                                    365
# Denmark                                    365
# Estonia                                    365
# Finland                                    365
# France                                     365
# Germany                                    365
# Greece                                     365
# Hungary                                    365
# Iceland                                    365
# Ireland                                    365
# Italy                                      365
# Latvia                                     365
# Lithuania                                  365
# Luxembourg                                 365
# Malta                                      365
# Moldova                                      0
# Netherlands                                365
# Norway                                     365
# Poland                                     365
# Portugal                                   365
# Romania                                    365
# Serbia                                       0
# Slovakia                                   365
# Slovenia                                   365
# Spain                                      365
# Sweden                                     365
# Switzerland                                365
# Ukraine                                    365
# United Kingdom                             365
#
#                         excess_mortality_cumulative_absolute  \
# Albania                                                  353
# Australia                                                313
# Austria                                                  313
# Belgium                                                  313
# Bosnia and Herzegovina                                   353
# Bulgaria                                                 313
# Canada                                                   313
# Croatia                                                  313
# Cyprus                                                   313
# Czechia                                                  313
# Denmark                                                  313
# Estonia                                                  313
# Finland                                                  313
# France                                                   313
# Germany                                                  313
# Greece                                                   313
# Hungary                                                  313
# Iceland                                                  313
# Ireland                                                  353
# Italy                                                    313
# Latvia                                                   313
# Lithuania                                                313
# Luxembourg                                               313
# Malta                                                    313
# Moldova                                                  353
# Netherlands                                              313
# Norway                                                   313
# Poland                                                   313
# Portugal                                                 313
# Romania                                                  313
# Serbia                                                   353
# Slovakia                                                 313
# Slovenia                                                 313
# Spain                                                    313
# Sweden                                                   313
# Switzerland                                              313
# Ukraine                                                  353
# United Kingdom                                           313
#
#                         excess_mortality_cumulative  excess_mortality
# Albania                                         353               353
# Australia                                       313               313
# Austria                                         313               313
# Belgium                                         313               313
# Bosnia and Herzegovina                          353               353
# Bulgaria                                        313               313
# Canada                                          313               313
# Croatia                                         313               313
# Cyprus                                          313               313
# Czechia                                         313               313
# Denmark                                         313               313
# Estonia                                         313               313
# Finland                                         313               313
# France                                          313               313
# Germany                                         313               313
# Greece                                          313               313
# Hungary                                         313               313
# Iceland                                         313               313
# Ireland                                         353               353
# Italy                                           313               313
# Latvia                                          313               313
# Lithuania                                       313               313
# Luxembourg                                      313               313
# Malta                                           313               313
# Moldova                                         353               353
# Netherlands                                     313               313
# Norway                                          313               313
# Poland                                          313               313
# Portugal                                        313               313
# Romania                                         313               313
# Serbia                                          353               353
# Slovakia                                        313               313
# Slovenia                                        313               313
# Spain                                           313               313
# Sweden                                          313               313
# Switzerland                                     313               313
# Ukraine                                         353               353
# United Kingdom                                  313               313

# %%
# calculate percent missing NaN
def percent_missing(df):
    a = df.isnull().sum() * 100 / len(df)
    return a
percent_missing(df)
# Out:
# location                                 0.000000
# total_cases                              0.000000
# new_cases                                0.086518
# total_deaths                             0.000000
# new_deaths                               0.194665
# reproduction_rate                        0.000000
# icu_patients                            35.955299
# hosp_patients                           19.055516
# weekly_icu_admissions                   82.941601
# weekly_hosp_admissions                  69.625090
# total_tests                             13.215573
# new_tests                               13.417448
# positive_rate                            5.133381
# tests_per_case                           6.402307
# total_vaccinations                      28.031723
# people_vaccinated                       29.769286
# people_fully_vaccinated                 31.341024
# total_boosters                          66.135544
# new_vaccinations                        34.722422
# new_people_vaccinated_smoothed           2.249459
# stringency_index                         0.000000
# population                               0.000000
# population_density                       0.000000
# median_age                               0.000000
# aged_65_older                            0.000000
# aged_70_older                            2.631579
# gdp_per_capita                           0.000000
# extreme_poverty                         26.315789
# cardiovasc_death_rate                    0.000000
# diabetes_prevalence                      0.000000
# female_smokers                           0.000000
# male_smokers                             0.000000
# handwashing_facilities                  92.105263
# hospital_beds_per_thousand               0.000000
# life_expectancy                          0.000000
# human_development_index                  0.000000
# excess_mortality_cumulative_absolute    87.483778
# excess_mortality_cumulative             87.483778
# excess_mortality                        87.483778
# dtype: float64

# %%
df.shape[1]
# Out:
# 39

# %%
# drop columns with 50% or more NaNs
df.dropna(thresh=len(df)*0.5, axis=1, inplace=True)

# %%
df.shape[1]
# Out:
# 32

# %%
# check nans again 
pd.set_option('display.max_columns', None)

nans(df, countries_lst)
#and/or
percent_missing(df)
# Out:
# location                           0.000000
# total_cases                        0.000000
# new_cases                          0.086518
# total_deaths                       0.000000
# new_deaths                         0.194665
# reproduction_rate                  0.000000
# icu_patients                      35.955299
# hosp_patients                     19.055516
# total_tests                       13.215573
# new_tests                         13.417448
# positive_rate                      5.133381
# tests_per_case                     6.402307
# total_vaccinations                28.031723
# people_vaccinated                 29.769286
# people_fully_vaccinated           31.341024
# new_vaccinations                  34.722422
# new_people_vaccinated_smoothed     2.249459
# stringency_index                   0.000000
# population                         0.000000
# population_density                 0.000000
# median_age                         0.000000
# aged_65_older                      0.000000
# aged_70_older                      2.631579
# gdp_per_capita                     0.000000
# extreme_poverty                   26.315789
# cardiovasc_death_rate              0.000000
# diabetes_prevalence                0.000000
# female_smokers                     0.000000
# male_smokers                       0.000000
# hospital_beds_per_thousand         0.000000
# life_expectancy                    0.000000
# human_development_index            0.000000
# dtype: float64

# %%
def fill(df):    
    for col in df.select_dtypes(include=['float']).columns.tolist():
        # fill nulls for each country with the median value for each column
        for country in countries_lst:
            if df.loc[df['location'] == country, col].isnull().sum() == 365:
                df.loc[df['location'] == country, col] = df.loc[df['location'] == country, col].fillna(value=df[col].median())
            else:
                med = float(df.loc[df['location'] == country, col].median())
                df.loc[df['location'] == country, col] = df.loc[df['location'] == country, col].fillna(value=med)
    return df
fill(df)
# Out:
#               location  total_cases  new_cases  total_deaths  new_deaths  \
# 2090           Albania      58316.0        0.0        1181.0         0.0
# 2091           Albania      58991.0      675.0        1190.0         9.0
# 2092           Albania      59438.0      447.0        1193.0         3.0
# 2093           Albania      59623.0      185.0        1199.0         6.0
# 2094           Albania      60283.0      660.0        1210.0        11.0
# ...                ...          ...        ...           ...         ...
# 192031  United Kingdom   12263927.0   107771.0      148125.0       143.0
# 192032  United Kingdom   12402073.0   138146.0      148144.0        19.0
# 192033  United Kingdom   12584985.0   182912.0      148202.0        58.0
# 192034  United Kingdom   12774047.0   189062.0      148534.0       332.0
# 192035  United Kingdom   12964690.0   190643.0      148737.0       203.0
#
#         reproduction_rate  icu_patients  hosp_patients  total_tests  \
# 2090                 0.96         209.0          742.0     249384.0
# 2091                 0.98         209.0          742.0     250409.0
# 2092                 1.00         209.0          742.0     252718.0
# 2093                 1.01         209.0          742.0     253999.0
# 2094                 1.03         209.0          742.0     257423.0
# ...                   ...           ...            ...          ...
# 192031               1.32         870.0         9913.0  386752248.0
# 192032               1.32         851.0        11075.0  388303628.0
# 192033               1.32         868.0        12123.0  389886084.0
# 192034               1.31         875.0        13314.0  391519809.0
# 192035               1.29         883.0        14347.0  393314236.0
#
#         new_tests  positive_rate  tests_per_case  total_vaccinations  \
# 2090       1858.0         0.1940             5.2           1021408.0
# 2091       1025.0         0.2268             4.4           1021408.0
# 2092       2309.0         0.2209             4.5           1021408.0
# 2093       1281.0         0.2150             4.7           1021408.0
# 2094       3424.0         0.2101             4.8           1021408.0
# ...           ...            ...             ...                 ...
# 192031  1388049.0         0.0742            13.5         131743125.0
# 192032  1551380.0         0.0789            12.7         132121605.0
# 192033  1582456.0         0.0874            11.4         132633271.0
# 192034  1633725.0         0.0948            10.6         133108303.0
# 192035  1794427.0         0.1001            10.0         133312817.0
#
#         people_vaccinated  people_fully_vaccinated  new_vaccinations  \
# 2090             761467.5                 601104.0            8134.0
# 2091             761467.5                 601104.0            8134.0
# 2092             761467.5                 601104.0            8134.0
# 2093             761467.5                 601104.0            8134.0
# 2094             761467.5                 601104.0            8134.0
# ...                   ...                      ...               ...
# 192031         51681547.0               47294774.0          315382.0
# 192032         51705406.0               47324308.0          378480.0
# 192033         51738013.0               47368074.0          511666.0
# 192034         51771384.0               47412181.0          475032.0
# 192035         51786768.0               47434251.0          204514.0
#
#         new_people_vaccinated_smoothed  stringency_index  population  \
# 2090                            2661.0             56.48   2854710.0
# 2091                            2661.0             56.48   2854710.0
# 2092                            2661.0             56.48   2854710.0
# 2093                            2661.0             56.48   2854710.0
# 2094                            2661.0             56.48   2854710.0
# ...                                ...               ...         ...
# 192031                         20531.0             48.61  67281040.0
# 192032                         18232.0             48.61  67281040.0
# 192033                         17275.0             48.61  67281040.0
# 192034                         17384.0             48.61  67281040.0
# 192035                         18043.0             48.61  67281040.0
#
#         population_density  median_age  aged_65_older  aged_70_older  \
# 2090               104.871        38.0         13.188          8.643
# 2091               104.871        38.0         13.188          8.643
# 2092               104.871        38.0         13.188          8.643
# 2093               104.871        38.0         13.188          8.643
# 2094               104.871        38.0         13.188          8.643
# ...                    ...         ...            ...            ...
# 192031             272.898        40.8         18.517         12.527
# 192032             272.898        40.8         18.517         12.527
# 192033             272.898        40.8         18.517         12.527
# 192034             272.898        40.8         18.517         12.527
# 192035             272.898        40.8         18.517         12.527
#
#         gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 2090         11803.431              1.1                304.195
# 2091         11803.431              1.1                304.195
# 2092         11803.431              1.1                304.195
# 2093         11803.431              1.1                304.195
# 2094         11803.431              1.1                304.195
# ...                ...              ...                    ...
# 192031       39753.244              0.2                122.137
# 192032       39753.244              0.2                122.137
# 192033       39753.244              0.2                122.137
# 192034       39753.244              0.2                122.137
# 192035       39753.244              0.2                122.137
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 2090                  10.08             7.1          51.2
# 2091                  10.08             7.1          51.2
# 2092                  10.08             7.1          51.2
# 2093                  10.08             7.1          51.2
# 2094                  10.08             7.1          51.2
# ...                     ...             ...           ...
# 192031                 4.28            20.0          24.7
# 192032                 4.28            20.0          24.7
# 192033                 4.28            20.0          24.7
# 192034                 4.28            20.0          24.7
# 192035                 4.28            20.0          24.7
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index
# 2090                          2.89            78.57                    0.795
# 2091                          2.89            78.57                    0.795
# 2092                          2.89            78.57                    0.795
# 2093                          2.89            78.57                    0.795
# 2094                          2.89            78.57                    0.795
# ...                            ...              ...                      ...
# 192031                        2.54            81.32                    0.932
# 192032                        2.54            81.32                    0.932
# 192033                        2.54            81.32                    0.932
# 192034                        2.54            81.32                    0.932
# 192035                        2.54            81.32                    0.932
#
# [13870 rows x 32 columns]

# %%
# remove location, no longer needed
df.drop(['location'], axis=1, inplace=True)

df.columns
# Out:
# Index(['total_cases', 'new_cases', 'total_deaths', 'new_deaths',
#        'reproduction_rate', 'icu_patients', 'hosp_patients', 'total_tests',
#        'new_tests', 'positive_rate', 'tests_per_case', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_people_vaccinated_smoothed', 'stringency_index', 'population',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'hospital_beds_per_thousand', 'life_expectancy',
#        'human_development_index'],
#       dtype='object')

# %% [markdown]
# ### Detecting outliers
# The best way to find outliers is too see which values fall outside the lower and upper bounds of the interquartile range. We create a dataframe to see portion of values in a column that fit this criteria. However, we decide not to remove or alter these outliers just yet -- these 'outliers' could be motivated by peaks of waves of covid (e.g., delta variant) which we know result in huge spikes of cases, deaths, vaccinations, and other variables in this dataset. They could also represent natural differences in features between countries covered in our dataset.

# %%
def outliers(df):
    UB_lst = []
    LB_lst = [] 
    for col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        LB = Q1 - 1.5*IQR
        UB = Q3 + 1.5*IQR
        #df.loc[df[col] > UB,col] = UB
        UB_lst.append(df[df[col] > UB].shape[0]/ df[col].count())
        #df.loc[df[col] < LB,col] = LB
        LB_lst.append(df[df[col] < LB].shape[0]/ df[col].count())
    return UB_lst, LB_lst
outlier_df = pd.DataFrame(data=outliers(df), columns=df.columns, index=['>UB', '<LB'])
outlier_df
# Out:
#      total_cases  new_cases  total_deaths  new_deaths  reproduction_rate  \
# >UB     0.122927   0.122927      0.149603    0.122422           0.009805
# <LB     0.000000   0.000000      0.000000    0.000000           0.000000
#
#      icu_patients  hosp_patients  total_tests  new_tests  positive_rate  \
# >UB      0.139798        0.14535      0.11478   0.140303       0.056597
# <LB      0.000000        0.00000      0.00000   0.000000       0.000000
#
#      tests_per_case  total_vaccinations  people_vaccinated  \
# >UB        0.113194            0.135472           0.143259
# <LB        0.000000            0.000000           0.000000
#
#      people_fully_vaccinated  new_vaccinations  \
# >UB                 0.128335          0.141312
# <LB                 0.000000          0.000000
#
#      new_people_vaccinated_smoothed  stringency_index  population  \
# >UB                        0.108652               0.0    0.131579
# <LB                        0.000000               0.0    0.000000
#
#      population_density  median_age  aged_65_older  aged_70_older  \
# >UB            0.105263         0.0       0.000000            0.0
# <LB            0.000000         0.0       0.026316            0.0
#
#      gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# >UB        0.026316         0.105263                    0.0
# <LB        0.000000         0.000000                    0.0
#
#      diabetes_prevalence  female_smokers  male_smokers  \
# >UB                  0.0        0.000000           0.0
# <LB                  0.0        0.052632           0.0
#
#      hospital_beds_per_thousand  life_expectancy  human_development_index
# >UB                         0.0              0.0                      0.0
# <LB                         0.0              0.0                      0.0

# %% [markdown]
# For good measure we compare the mean and median for each columns, nothing appears to be particularily off and we decide not to touch the outliers:

# %%
def mean_median(df):
    mm_lst = []
    for col in df.columns:
        mm_lst.append(df[col].agg(['mean', 'median']))
    return mm_lst
mean_median_df = pd.DataFrame(data = mean_median(df), columns = ['mean', 'median'])
mean_median_df
# Out:
#                                         mean        median
# total_cases                     1.194630e+06  5.238410e+05
# new_cases                       4.267791e+03  9.890000e+02
# total_deaths                    2.480839e+04  1.063500e+04
# new_deaths                      5.360552e+01  1.100000e+01
# reproduction_rate               1.043760e+00  1.030000e+00
# icu_patients                    4.439689e+02  2.090000e+02
# hosp_patients                   2.592333e+03  7.420000e+02
# total_tests                     2.339889e+07  8.086934e+06
# new_tests                       8.866889e+04  2.241300e+04
# positive_rate                   7.608975e-02  4.820000e-02
# tests_per_case                  7.309056e+01  2.070000e+01
# total_vaccinations              1.294937e+07  3.861969e+06
# people_vaccinated               7.301555e+06  2.395333e+06
# people_fully_vaccinated         5.747281e+06  1.571568e+06
# new_vaccinations                7.819397e+04  2.332100e+04
# new_people_vaccinated_smoothed  3.350721e+04  8.225000e+03
# stringency_index                5.448020e+01  5.278000e+01
# population                      1.718436e+07  7.788637e+06
# population_density              1.523950e+02  1.037450e+02
# median_age                      4.221053e+01  4.245000e+01
# aged_65_older                   1.800721e+01  1.867800e+01
# aged_70_older                   1.198918e+01  1.232500e+01
# gdp_per_capita                  3.557107e+04  3.343913e+04
# extreme_poverty                 6.947368e-01  5.000000e-01
# cardiovasc_death_rate           2.093782e+02  1.535000e+02
# diabetes_prevalence             6.385526e+00  5.785000e+00
# female_smokers                  2.247895e+01  2.275000e+01
# male_smokers                    3.333421e+01  3.225000e+01
# hospital_beds_per_thousand      4.769211e+00  4.505000e+00
# life_expectancy                 8.000421e+01  8.132500e+01
# human_development_index         8.892368e-01  8.975000e-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13870 entries, 2090 to 192035
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   total_cases                     13870 non-null  float64
#  1   new_cases                       13870 non-null  float64
#  2   total_deaths                    13870 non-null  float64
#  3   new_deaths                      13870 non-null  float64
#  4   reproduction_rate               13870 non-null  float64
#  5   icu_patients                    13870 non-null  float64
#  6   hosp_patients                   13870 non-null  float64
#  7   total_tests                     13870 non-null  float64
#  8   new_tests                       13870 non-null  float64
#  9   positive_rate                   13870 non-null  float64
#  10  tests_per_case                  13870 non-null  float64
#  11  total_vaccinations              13870 non-null  float64
#  12  people_vaccinated               13870 non-null  float64
#  13  people_fully_vaccinated         13870 non-null  float64
#  14  new_vaccinations                13870 non-null  float64
#  15  new_people_vaccinated_smoothed  13870 non-null  float64
#  16  stringency_index                13870 non-null  float64
#  17  population                      13870 non-null  float64
#  18  population_density              13870 non-null  float64
#  19  median_age                      13870 non-null  float64
#  20  aged_65_older                   13870 non-null  float64
#  21  aged_70_older                   13870 non-null  float64
#  22  gdp_per_capita                  13870 non-null  float64
#  23  extreme_poverty                 13870 non-null  float64
#  24  cardiovasc_death_rate           13870 non-null  float64
#  25  diabetes_prevalence             13870 non-null  float64
#  26  female_smokers                  13870 non-null  float64
#  27  male_smokers                    13870 non-null  float64
#  28  hospital_beds_per_thousand      13870 non-null  float64
#  29  life_expectancy                 13870 non-null  float64
#  30  human_development_index         13870 non-null  float64
# dtypes: float64(31)
# memory usage: 3.4 MB

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)
